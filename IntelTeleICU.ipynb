# %% [markdown]
# Importing all the libraries.

# %%
# !pip install ultralytics==8.0.196
# !pip install roboflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 631.1/631.1 kB 6.1 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %% [markdown]
# Importing os to Locate the directory.

# %%
import os
location = os.getcwd()          # COLLECTING THE LOCATION
print(location)
# Out:
# /content

# %% [markdown]
# Importing YOLO ("You Only Look Once") module from Ultralytics.

# %%
from ultralytics import YOLO

# %% [markdown]
# Importing dataset from roboflow.

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="3f0NYki9nbr6vHA5Imq4")
project = rf.workspace("robotele").project("intel-dataset")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Intel-DataSet-1 in yolov8:: 100%|██████████| 412/412 [00:00<00:00, 3405.19it/s]

# %% [markdown]
# Training Custom Dataset.

# %%
# %cd {location}   # TO CHANGE THE DICTIONARY
# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=100 imgsz=800 plots=True   #CONVERTING DATASET INTO yaml FORMAT.
# Out:
# [Errno 2] No such file or directory: '/content # TO CHANGE THE DICTIONARY'
# /content
# ...
# 100% 21.5M/21.5M [00:00<00:00, 279MB/s]
# New https://pypi.org/project/ultralytics/8.2.54 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# Implementing and Testing put the path of the file after uploading it on colab with proper extention mp4,png,jpg etc.

# %%
# %cd {location}
# !yolo task=detect mode=predict model={location}/runs/detect/train/weights/best.pt conf=0.25 source="PUT THE NAME OF FILE HERE"
# Out:
# /content
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
#
# video 1/1 (1/350) /content/te3.mp4: 480x800 3 Stables, 110.0ms
# video 1/1 (2/350) /content/te3.mp4: 480x800 2 Stables, 15.6ms
# video 1/1 (3/350) /content/te3.mp4: 480x800 2 Stables, 15.5ms
# video 1/1 (4/350) /content/te3.mp4: 480x800 1 Stable, 15.5ms
# video 1/1 (5/350) /content/te3.mp4: 480x800 2 Stables, 15.6ms
# video 1/1 (6/350) /content/te3.mp4: 480x800 2 Stables, 15.5ms
# video 1/1 (7/350) /content/te3.mp4: 480x800 2 Stables, 15.6ms
# video 1/1 (8/350) /content/te3.mp4: 480x800 2 Stables, 15.5ms
# video 1/1 (9/350) /content/te3.mp4: 480x800 3 Stables, 14.4ms
# video 1/1 (10/350) /content/te3.mp4: 480x800 2 Stables, 11.1ms
# video 1/1 (11/350) /content/te3.mp4: 480x800 2 Stables, 11.0ms
# video 1/1 (12/350) /content/te3.mp4: 480x800 3 Stables, 11.1ms
# ...
